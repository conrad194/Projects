# %% [markdown]
# Doing some analasis on the following link
# ```
# https://theunitedstates.io/congress-legislators/legislators-current.csv
# ```

# %%
import pandas as pd
df = pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-current.csv")
df
# Out:
#      last_name first_name middle_name suffix nickname              full_name  \
# 0        Brown    Sherrod         NaN    NaN      NaN          Sherrod Brown
# 1     Cantwell      Maria         NaN    NaN      NaN         Maria Cantwell
# 2       Cardin   Benjamin          L.    NaN      NaN     Benjamin L. Cardin
# 3       Carper     Thomas     Richard    NaN      NaN       Thomas R. Carper
# 4        Casey     Robert          P.    Jr.      Bob   Robert P. Casey, Jr.
# ..         ...        ...         ...    ...      ...                    ...
# 534  Van Orden    Derrick     Francis    NaN      NaN      Derrick Van Orden
# 535    Hageman    Harriet      Maxine    NaN      NaN     Harriet M. Hageman
# 536   Ricketts       Pete         NaN    NaN      NaN          Pete Ricketts
# 537  McClellan   Jennifer         NaN    NaN      NaN  Jennifer L. McClellan
# 538     Butler   Laphonza   Romanique    NaN      NaN     Laphonza R. Butler
#
#        birthday gender type state  district  senate_class       party  \
# 0    1952-11-09      M  sen    OH       NaN           1.0    Democrat
# 1    1958-10-13      F  sen    WA       NaN           1.0    Democrat
# 2    1943-10-05      M  sen    MD       NaN           1.0    Democrat
# 3    1947-01-23      M  sen    DE       NaN           1.0    Democrat
# 4    1960-04-13      M  sen    PA       NaN           1.0    Democrat
# ..          ...    ...  ...   ...       ...           ...         ...
# 534  1969-09-15      M  rep    WI       3.0           NaN  Republican
# 535  1962-10-18      F  rep    WY       0.0           NaN  Republican
# 536  1964-08-19      M  sen    NE       NaN           2.0  Republican
# 537  1972-12-28      F  rep    VA       4.0           NaN    Democrat
# 538  1979-05-11      F  sen    CA       NaN           1.0    Democrat
#
#                                  url  \
# 0       https://www.brown.senate.gov
# 1    https://www.cantwell.senate.gov
# 2      https://www.cardin.senate.gov
# 3      https://www.carper.senate.gov
# 4       https://www.casey.senate.gov
# ..                               ...
# 534      https://vanorden.house.gov/
# 535       https://hageman.house.gov/
# 536  https://www.ricketts.senate.gov
# 537                              NaN
# 538    https://www.butler.senate.gov
#
#                                                address         phone  \
# 0    503 Hart Senate Office Building Washington DC ...  202-224-2315
# 1    511 Hart Senate Office Building Washington DC ...  202-224-3441
# 2    509 Hart Senate Office Building Washington DC ...  202-224-4524
# 3    513 Hart Senate Office Building Washington DC ...  202-224-2441
# 4    393 Russell Senate Office Building Washington ...  202-224-6324
# ..                                                 ...           ...
# 534  1513 Longworth House Office Building Washingto...  202-225-5506
# 535  1531 Longworth House Office Building Washingto...  202-225-2311
# 536  139 Russell Senate Office Building Washington ...  202-224-4224
# 537  2417 Rayburn House Office Building Washington ...  202-225-6365
# 538  G12 Dirksen Senate Office Building Washington ...  202-224-3841
#
#                                           contact_form  \
# 0                https://www.brown.senate.gov/contact/
# 1    https://www.cantwell.senate.gov/public/index.c...
# 2               https://www.cardin.senate.gov/contact/
# 3               https://www.carper.senate.gov/contact/
# 4                 https://www.casey.senate.gov/contact
# ..                                                 ...
# 534                                                NaN
# 535                                                NaN
# 536                                                NaN
# 537                                                NaN
# 538                     https://www.butler.senate.gov/
#
#                                                rss_url          twitter  \
# 0    http://www.brown.senate.gov/rss/feeds/?type=al...  SenSherrodBrown
# 1    http://www.cantwell.senate.gov/public/index.cf...  SenatorCantwell
# 2     http://www.cardin.senate.gov/rss/feeds/?type=all    SenatorCardin
# 3    http://www.carper.senate.gov/public/index.cfm/...    SenatorCarper
# 4           http://www.casey.senate.gov/rss/feeds/?all      SenBobCasey
# ..                                                 ...              ...
# 534                                                NaN      RepVanOrden
# 535                                                NaN              NaN
# 536                                                NaN              NaN
# 537                                                NaN              NaN
# 538                                                NaN              NaN
#
#        twitter_id             facebook           youtube  \
# 0    4.391080e+07  SenatorSherrodBrown  SherrodBrownOhio
# 1    1.175020e+08      senatorcantwell   SenatorCantwell
# 2    1.090710e+08     senatorbencardin     senatorcardin
# 3    2.497879e+08            tomcarper     senatorcarper
# 4    1.715987e+08      SenatorBobCasey   SenatorBobCasey
# ..            ...                  ...               ...
# 534  1.598778e+18                  NaN               NaN
# 535           NaN                  NaN               NaN
# 536           NaN                  NaN               NaN
# 537           NaN                  NaN               NaN
# 538           NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 0    UCgy8jfERh-t_ixkKKoCmglQ      NaN     B000944      136.0      N00003535
# 1    UCN52UDqKgvHRk39ncySrIMw      NaN     C000127      172.0      N00007836
# 2    UCiQaJnMzlfzzG3VESgyZChA      NaN     C000141      174.0      N00001955
# 3    UCgLnvbKwu4B3navofj6Qvvw      NaN     C000174      179.0      N00012508
# 4    UCtVssXhx-KuZa-hSvnsnJ0A      NaN     C001070     1828.0      N00027503
# ..                        ...      ...         ...        ...            ...
# 534                       NaN      NaN     V000135        NaN            NaN
# 535                       NaN      NaN     H001096        NaN            NaN
# 536                       NaN      NaN     R000618        NaN            NaN
# 537                       NaN      NaN     M001227        NaN            NaN
# 538                       NaN      NaN     B001320        NaN            NaN
#
#     lis_id              fec_ids  cspan_id  govtrack_id  votesmart_id  \
# 0     S307  H2OH13033,S6OH00163    5051.0       400050       27018.0
# 1     S275  S8WA00194,H2WA01054   26137.0       300018       27122.0
# 2     S308  H6MD03177,S6MD03177    4004.0       400064       26888.0
# 3     S277            S8DE00079     663.0       300019       22421.0
# 4     S309            S6PA00217   47036.0       412246        2541.0
# ..     ...                  ...       ...          ...           ...
# 534    NaN            H0WI03175       NaN       456950      192343.0
# 535    NaN            H2WY00166       NaN       456951      182961.0
# 536   S423            S6NE00129   61233.0       456952       57777.0
# 537    NaN            H4VA04066       NaN       456953       58655.0
# 538   S424                  NaN       NaN       456954           NaN
#
#          ballotpedia_id  washington_post_id  icpsr_id        wikipedia_id
# 0         Sherrod Brown                 NaN   29389.0       Sherrod Brown
# 1        Maria Cantwell                 NaN   39310.0      Maria Cantwell
# 2            Ben Cardin                 NaN   15408.0          Ben Cardin
# 3            Tom Carper                 NaN   15015.0          Tom Carper
# 4        Bob Casey, Jr.                 NaN   40703.0       Bob Casey Jr.
# ..                  ...                 ...       ...                 ...
# 534   Derrick Van Orden                 NaN       NaN   Derrick Van Orden
# 535     Harriet Hageman                 NaN       NaN     Harriet Hageman
# 536       Pete Ricketts                 NaN       NaN       Pete Ricketts
# 537  Jennifer McClellan                 NaN       NaN  Jennifer McClellan
# 538     Laphonza Butler                 NaN       NaN     Laphonza Butler
#
# [539 rows x 36 columns]

# %% [markdown]
# ## Show All Columns
#
# This dataset has **A LOT** of columns!  By default, pandas will not show all of them.  By setting the `display.max_columns` value we can view all the columns:

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#      last_name first_name middle_name suffix nickname              full_name  \
# 0        Brown    Sherrod         NaN    NaN      NaN          Sherrod Brown
# 1     Cantwell      Maria         NaN    NaN      NaN         Maria Cantwell
# 2       Cardin   Benjamin          L.    NaN      NaN     Benjamin L. Cardin
# 3       Carper     Thomas     Richard    NaN      NaN       Thomas R. Carper
# 4        Casey     Robert          P.    Jr.      Bob   Robert P. Casey, Jr.
# ..         ...        ...         ...    ...      ...                    ...
# 534  Van Orden    Derrick     Francis    NaN      NaN      Derrick Van Orden
# 535    Hageman    Harriet      Maxine    NaN      NaN     Harriet M. Hageman
# 536   Ricketts       Pete         NaN    NaN      NaN          Pete Ricketts
# 537  McClellan   Jennifer         NaN    NaN      NaN  Jennifer L. McClellan
# 538     Butler   Laphonza   Romanique    NaN      NaN     Laphonza R. Butler
#
#        birthday gender type state  district  senate_class       party  \
# 0    1952-11-09      M  sen    OH       NaN           1.0    Democrat
# 1    1958-10-13      F  sen    WA       NaN           1.0    Democrat
# 2    1943-10-05      M  sen    MD       NaN           1.0    Democrat
# 3    1947-01-23      M  sen    DE       NaN           1.0    Democrat
# 4    1960-04-13      M  sen    PA       NaN           1.0    Democrat
# ..          ...    ...  ...   ...       ...           ...         ...
# 534  1969-09-15      M  rep    WI       3.0           NaN  Republican
# 535  1962-10-18      F  rep    WY       0.0           NaN  Republican
# 536  1964-08-19      M  sen    NE       NaN           2.0  Republican
# 537  1972-12-28      F  rep    VA       4.0           NaN    Democrat
# 538  1979-05-11      F  sen    CA       NaN           1.0    Democrat
#
#                                  url  \
# 0       https://www.brown.senate.gov
# 1    https://www.cantwell.senate.gov
# 2      https://www.cardin.senate.gov
# 3      https://www.carper.senate.gov
# 4       https://www.casey.senate.gov
# ..                               ...
# 534      https://vanorden.house.gov/
# 535       https://hageman.house.gov/
# 536  https://www.ricketts.senate.gov
# 537                              NaN
# 538    https://www.butler.senate.gov
#
#                                                address         phone  \
# 0    503 Hart Senate Office Building Washington DC ...  202-224-2315
# 1    511 Hart Senate Office Building Washington DC ...  202-224-3441
# 2    509 Hart Senate Office Building Washington DC ...  202-224-4524
# 3    513 Hart Senate Office Building Washington DC ...  202-224-2441
# 4    393 Russell Senate Office Building Washington ...  202-224-6324
# ..                                                 ...           ...
# 534  1513 Longworth House Office Building Washingto...  202-225-5506
# 535  1531 Longworth House Office Building Washingto...  202-225-2311
# 536  139 Russell Senate Office Building Washington ...  202-224-4224
# 537  2417 Rayburn House Office Building Washington ...  202-225-6365
# 538  G12 Dirksen Senate Office Building Washington ...  202-224-3841
#
#                                           contact_form  \
# 0                https://www.brown.senate.gov/contact/
# 1    https://www.cantwell.senate.gov/public/index.c...
# 2               https://www.cardin.senate.gov/contact/
# 3               https://www.carper.senate.gov/contact/
# 4                 https://www.casey.senate.gov/contact
# ..                                                 ...
# 534                                                NaN
# 535                                                NaN
# 536                                                NaN
# 537                                                NaN
# 538                     https://www.butler.senate.gov/
#
#                                                rss_url          twitter  \
# 0    http://www.brown.senate.gov/rss/feeds/?type=al...  SenSherrodBrown
# 1    http://www.cantwell.senate.gov/public/index.cf...  SenatorCantwell
# 2     http://www.cardin.senate.gov/rss/feeds/?type=all    SenatorCardin
# 3    http://www.carper.senate.gov/public/index.cfm/...    SenatorCarper
# 4           http://www.casey.senate.gov/rss/feeds/?all      SenBobCasey
# ..                                                 ...              ...
# 534                                                NaN      RepVanOrden
# 535                                                NaN              NaN
# 536                                                NaN              NaN
# 537                                                NaN              NaN
# 538                                                NaN              NaN
#
#        twitter_id             facebook           youtube  \
# 0    4.391080e+07  SenatorSherrodBrown  SherrodBrownOhio
# 1    1.175020e+08      senatorcantwell   SenatorCantwell
# 2    1.090710e+08     senatorbencardin     senatorcardin
# 3    2.497879e+08            tomcarper     senatorcarper
# 4    1.715987e+08      SenatorBobCasey   SenatorBobCasey
# ..            ...                  ...               ...
# 534  1.598778e+18                  NaN               NaN
# 535           NaN                  NaN               NaN
# 536           NaN                  NaN               NaN
# 537           NaN                  NaN               NaN
# 538           NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 0    UCgy8jfERh-t_ixkKKoCmglQ      NaN     B000944      136.0      N00003535
# 1    UCN52UDqKgvHRk39ncySrIMw      NaN     C000127      172.0      N00007836
# 2    UCiQaJnMzlfzzG3VESgyZChA      NaN     C000141      174.0      N00001955
# 3    UCgLnvbKwu4B3navofj6Qvvw      NaN     C000174      179.0      N00012508
# 4    UCtVssXhx-KuZa-hSvnsnJ0A      NaN     C001070     1828.0      N00027503
# ..                        ...      ...         ...        ...            ...
# 534                       NaN      NaN     V000135        NaN            NaN
# 535                       NaN      NaN     H001096        NaN            NaN
# 536                       NaN      NaN     R000618        NaN            NaN
# 537                       NaN      NaN     M001227        NaN            NaN
# 538                       NaN      NaN     B001320        NaN            NaN
#
#     lis_id              fec_ids  cspan_id  govtrack_id  votesmart_id  \
# 0     S307  H2OH13033,S6OH00163    5051.0       400050       27018.0
# 1     S275  S8WA00194,H2WA01054   26137.0       300018       27122.0
# 2     S308  H6MD03177,S6MD03177    4004.0       400064       26888.0
# 3     S277            S8DE00079     663.0       300019       22421.0
# 4     S309            S6PA00217   47036.0       412246        2541.0
# ..     ...                  ...       ...          ...           ...
# 534    NaN            H0WI03175       NaN       456950      192343.0
# 535    NaN            H2WY00166       NaN       456951      182961.0
# 536   S423            S6NE00129   61233.0       456952       57777.0
# 537    NaN            H4VA04066       NaN       456953       58655.0
# 538   S424                  NaN       NaN       456954           NaN
#
#          ballotpedia_id  washington_post_id  icpsr_id        wikipedia_id
# 0         Sherrod Brown                 NaN   29389.0       Sherrod Brown
# 1        Maria Cantwell                 NaN   39310.0      Maria Cantwell
# 2            Ben Cardin                 NaN   15408.0          Ben Cardin
# 3            Tom Carper                 NaN   15015.0          Tom Carper
# 4        Bob Casey, Jr.                 NaN   40703.0       Bob Casey Jr.
# ..                  ...                 ...       ...                 ...
# 534   Derrick Van Orden                 NaN       NaN   Derrick Van Orden
# 535     Harriet Hageman                 NaN       NaN     Harriet Hageman
# 536       Pete Ricketts                 NaN       NaN       Pete Ricketts
# 537  Jennifer McClellan                 NaN       NaN  Jennifer McClellan
# 538     Laphonza Butler                 NaN       NaN     Laphonza Butler
#
# [539 rows x 36 columns]

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 1: Splitting The House of Representatives and The Senate
#
# In this dataset, each row is one member of Congress.  The United States Congress is bicameral, being made up of both the House of Representatives and the Senate.  In the dataset:
#
# - Representatives in the House of Representatives represent a district, which is encoded in the `district` column.  Their `type` column is also `rep`.
# - Senators are elected for six years, with one-third of the senators up for election every two years.  The `senate_class` denotes which election class a senator is in.  A seantor's `type` column is `sen`.
#
# Create two new DataFrames, `df_house` and `df_senate`, that contain members of the House of Representatives and the Senate:

# %%
df_house = df[df.type == 'rep']
df_house
# Out:
#              last_name first_name middle_name suffix nickname  \
# 26            Aderholt     Robert          B.    NaN      NaN
# 29           Bilirakis        Gus          M.    NaN      NaN
# 30              Bishop    Sanford          D.    Jr.      NaN
# 32          Blumenauer       Earl         NaN    NaN      NaN
# 35            Buchanan       Vern         NaN    NaN      NaN
# ..                 ...        ...         ...    ...      ...
# 532             Balint      Becca          A.    NaN      NaN
# 533  Gluesenkamp Perez      Marie         NaN    NaN      NaN
# 534          Van Orden    Derrick     Francis    NaN      NaN
# 535            Hageman    Harriet      Maxine    NaN      NaN
# 537          McClellan   Jennifer         NaN    NaN      NaN
#
#                    full_name    birthday gender type state  district  \
# 26        Robert B. Aderholt  1965-07-22      M  rep    AL       4.0
# 29          Gus M. Bilirakis  1963-02-08      M  rep    FL      12.0
# 30    Sanford D. Bishop, Jr.  1947-02-04      M  rep    GA       2.0
# 32           Earl Blumenauer  1948-08-16      M  rep    OR       3.0
# 35             Vern Buchanan  1951-05-08      M  rep    FL      16.0
# ..                       ...         ...    ...  ...   ...       ...
# 532             Becca Balint  1968-05-04      F  rep    VT       0.0
# 533  Marie Gluesenkamp Perez  1988-06-06      F  rep    WA       3.0
# 534        Derrick Van Orden  1969-09-15      M  rep    WI       3.0
# 535       Harriet M. Hageman  1962-10-18      F  rep    WY       0.0
# 537    Jennifer L. McClellan  1972-12-28      F  rep    VA       4.0
#
#      senate_class       party                                  url  \
# 26            NaN  Republican           https://aderholt.house.gov
# 29            NaN  Republican          https://bilirakis.house.gov
# 30            NaN    Democrat             https://bishop.house.gov
# 32            NaN    Democrat         https://blumenauer.house.gov
# 35            NaN  Republican           https://buchanan.house.gov
# ..            ...         ...                                  ...
# 532           NaN    Democrat            https://balint.house.gov/
# 533           NaN    Democrat  https://gluesenkampperez.house.gov/
# 534           NaN  Republican          https://vanorden.house.gov/
# 535           NaN  Republican           https://hageman.house.gov/
# 537           NaN    Democrat                                  NaN
#
#                                                address         phone  \
# 26   266 Cannon House Office Building Washington DC...  202-225-4876
# 29   2306 Rayburn House Office Building Washington ...  202-225-5755
# 30   2407 Rayburn House Office Building Washington ...  202-225-3631
# 32   1111 Longworth House Office Building Washingto...  202-225-4811
# 35   2110 Rayburn House Office Building Washington ...  202-225-5015
# ..                                                 ...           ...
# 532  1408 Longworth House Office Building Washingto...  202-225-4115
# 533  1431 Longworth House Office Building Washingto...  202-225-3536
# 534  1513 Longworth House Office Building Washingto...  202-225-5506
# 535  1531 Longworth House Office Building Washingto...  202-225-2311
# 537  2417 Rayburn House Office Building Washington ...  202-225-6365
#
#     contact_form                                            rss_url  \
# 26           NaN  http://aderholt.house.gov/common/rss//index.cf...
# 29           NaN  http://bilirakis.house.gov/index.php?format=fe...
# 30           NaN                    http://bishop.house.gov/rss.xml
# 32           NaN  http://blumenauer.house.gov/index.php?format=f...
# 35           NaN  http://buchanan.house.gov/index.php?option=com...
# ..           ...                                                ...
# 532          NaN                                                NaN
# 533          NaN                                                NaN
# 534          NaN                                                NaN
# 535          NaN                                                NaN
# 537          NaN                                                NaN
#
#              twitter    twitter_id             facebook           youtube  \
# 26   Robert_Aderholt  7.645276e+07       RobertAderholt    RobertAderholt
# 29   RepGusBilirakis  2.605168e+07         GusBilirakis   RepGusBilirakis
# 30     SanfordBishop  2.494105e+08        sanfordbishop  RepSanfordBishop
# 32   BlumenauerMedia  1.378240e+08                  NaN     RepBlumenauer
# 35      VernBuchanan  2.046716e+07  CongressmanBuchanan      vernbuchanan
# ..               ...           ...                  ...               ...
# 532        RepBeccaB  1.606115e+18                  NaN               NaN
# 533           RepMGP  1.603128e+18                  NaN               NaN
# 534      RepVanOrden  1.598778e+18                  NaN               NaN
# 535              NaN           NaN                  NaN               NaN
# 537              NaN           NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 26   UC71CAgpg1gbLTew_pfTneGA      NaN     A000055     1460.0      N00003028
# 29   UC2z1uu1n4-60xXs5x1mvLJw      NaN     B001257     1838.0      N00027462
# 30   UCxF9veLBrkr_CqVq5eFYVGg      NaN     B000490       91.0      N00002674
# 32   UCuziVoKuGn7feNA5VrpxsBQ      NaN     B000574       99.0      N00007727
# 35   UCY4DEy41NxOTdcF8_XAVZvw      NaN     B001260     1840.0      N00027626
# ..                        ...      ...         ...        ...            ...
# 532                       NaN      NaN     B001318        NaN            NaN
# 533                       NaN      NaN     G000600        NaN            NaN
# 534                       NaN      NaN     V000135        NaN            NaN
# 535                       NaN      NaN     H001096        NaN            NaN
# 537                       NaN      NaN     M001227        NaN            NaN
#
#     lis_id    fec_ids   cspan_id  govtrack_id  votesmart_id  \
# 26     NaN  H6AL04098    45516.0       400004         441.0
# 29     NaN  H6FL09070  1022873.0       412250       17318.0
# 30     NaN  H2GA02031    26194.0       400030       26817.0
# 32     NaN  H6OR03064    43809.0       400033         367.0
# 35     NaN  H6FL13148  1021626.0       412196       66247.0
# ..     ...        ...        ...          ...           ...
# 532    NaN  H2VT01076        NaN       456948      154056.0
# 533    NaN  H2WA03217        NaN       456949      207307.0
# 534    NaN  H0WI03175        NaN       456950      192343.0
# 535    NaN  H2WY00166        NaN       456951      182961.0
# 537    NaN  H4VA04066        NaN       456953       58655.0
#
#               ballotpedia_id  washington_post_id  icpsr_id  \
# 26        Robert B. Aderholt                 NaN   29701.0
# 29          Gus M. Bilirakis                 NaN   20758.0
# 30        Sanford Bishop Jr.                 NaN   29339.0
# 32           Earl Blumenauer                 NaN   29588.0
# 35             Vern Buchanan                 NaN   20709.0
# ..                       ...                 ...       ...
# 532                      NaN                 NaN       NaN
# 533  Marie Gluesenkamp Perez                 NaN       NaN
# 534        Derrick Van Orden                 NaN       NaN
# 535          Harriet Hageman                 NaN       NaN
# 537       Jennifer McClellan                 NaN       NaN
#
#                 wikipedia_id
# 26           Robert Aderholt
# 29             Gus Bilirakis
# 30            Sanford Bishop
# 32           Earl Blumenauer
# 35             Vern Buchanan
# ..                       ...
# 532             Becca Balint
# 533  Marie Gluesenkamp Perez
# 534        Derrick Van Orden
# 535          Harriet Hageman
# 537       Jennifer McClellan
#
# [439 rows x 36 columns]

# %%
df_senate = df[df.type == 'sen']
df_senate
# Out:
#      last_name    first_name middle_name suffix nickname  \
# 0        Brown       Sherrod         NaN    NaN      NaN
# 1     Cantwell         Maria         NaN    NaN      NaN
# 2       Cardin      Benjamin          L.    NaN      NaN
# 3       Carper        Thomas     Richard    NaN      NaN
# 4        Casey        Robert          P.    Jr.      Bob
# ..         ...           ...         ...    ...      ...
# 459    Schmitt          Eric     Stephen    NaN      NaN
# 460      Vance  J.D. (James)     (David)    NaN      NaN
# 461  Fetterman          John        Karl    NaN      NaN
# 536   Ricketts          Pete         NaN    NaN      NaN
# 538     Butler      Laphonza   Romanique    NaN      NaN
#
#                 full_name    birthday gender type state  district  \
# 0           Sherrod Brown  1952-11-09      M  sen    OH       NaN
# 1          Maria Cantwell  1958-10-13      F  sen    WA       NaN
# 2      Benjamin L. Cardin  1943-10-05      M  sen    MD       NaN
# 3        Thomas R. Carper  1947-01-23      M  sen    DE       NaN
# 4    Robert P. Casey, Jr.  1960-04-13      M  sen    PA       NaN
# ..                    ...         ...    ...  ...   ...       ...
# 459          Eric Schmitt  1975-06-20      M  sen    MO       NaN
# 460            J.D. Vance  1984-08-02      M  sen    OH       NaN
# 461        John Fetterman  1969-08-15      M  sen    PA       NaN
# 536         Pete Ricketts  1964-08-19      M  sen    NE       NaN
# 538    Laphonza R. Butler  1979-05-11      F  sen    CA       NaN
#
#      senate_class       party                               url  \
# 0             1.0    Democrat      https://www.brown.senate.gov
# 1             1.0    Democrat   https://www.cantwell.senate.gov
# 2             1.0    Democrat     https://www.cardin.senate.gov
# 3             1.0    Democrat     https://www.carper.senate.gov
# 4             1.0    Democrat      https://www.casey.senate.gov
# ..            ...         ...                               ...
# 459           3.0  Republican    https://www.schmitt.senate.gov
# 460           3.0  Republican      https://www.vance.senate.gov
# 461           3.0    Democrat  https://www.fetterman.senate.gov
# 536           2.0  Republican   https://www.ricketts.senate.gov
# 538           1.0    Democrat     https://www.butler.senate.gov
#
#                                                address         phone  \
# 0    503 Hart Senate Office Building Washington DC ...  202-224-2315
# 1    511 Hart Senate Office Building Washington DC ...  202-224-3441
# 2    509 Hart Senate Office Building Washington DC ...  202-224-4524
# 3    513 Hart Senate Office Building Washington DC ...  202-224-2441
# 4    393 Russell Senate Office Building Washington ...  202-224-6324
# ..                                                 ...           ...
# 459  387 Russell Senate Office Building Washington ...  202-224-5721
# 460  288 Russell Senate Office Building Washington ...  202-224-3353
# 461  142 Russell Senate Office Building Washington ...  202-224-4254
# 536  139 Russell Senate Office Building Washington ...  202-224-4224
# 538  G12 Dirksen Senate Office Building Washington ...  202-224-3841
#
#                                           contact_form  \
# 0                https://www.brown.senate.gov/contact/
# 1    https://www.cantwell.senate.gov/public/index.c...
# 2               https://www.cardin.senate.gov/contact/
# 3               https://www.carper.senate.gov/contact/
# 4                 https://www.casey.senate.gov/contact
# ..                                                 ...
# 459                    https://www.schmitt.senate.gov/
# 460                      https://www.vance.senate.gov/
# 461                  https://www.fetterman.senate.gov/
# 536                                                NaN
# 538                     https://www.butler.senate.gov/
#
#                                                rss_url          twitter  \
# 0    http://www.brown.senate.gov/rss/feeds/?type=al...  SenSherrodBrown
# 1    http://www.cantwell.senate.gov/public/index.cf...  SenatorCantwell
# 2     http://www.cardin.senate.gov/rss/feeds/?type=all    SenatorCardin
# 3    http://www.carper.senate.gov/public/index.cfm/...    SenatorCarper
# 4           http://www.casey.senate.gov/rss/feeds/?all      SenBobCasey
# ..                                                 ...              ...
# 459                                                NaN              NaN
# 460                                                NaN              NaN
# 461                                                NaN              NaN
# 536                                                NaN              NaN
# 538                                                NaN              NaN
#
#       twitter_id             facebook           youtube  \
# 0     43910797.0  SenatorSherrodBrown  SherrodBrownOhio
# 1    117501995.0      senatorcantwell   SenatorCantwell
# 2    109071031.0     senatorbencardin     senatorcardin
# 3    249787913.0            tomcarper     senatorcarper
# 4    171598736.0      SenatorBobCasey   SenatorBobCasey
# ..           ...                  ...               ...
# 459          NaN                  NaN               NaN
# 460          NaN                  NaN               NaN
# 461          NaN                  NaN               NaN
# 536          NaN                  NaN               NaN
# 538          NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 0    UCgy8jfERh-t_ixkKKoCmglQ      NaN     B000944      136.0      N00003535
# 1    UCN52UDqKgvHRk39ncySrIMw      NaN     C000127      172.0      N00007836
# 2    UCiQaJnMzlfzzG3VESgyZChA      NaN     C000141      174.0      N00001955
# 3    UCgLnvbKwu4B3navofj6Qvvw      NaN     C000174      179.0      N00012508
# 4    UCtVssXhx-KuZa-hSvnsnJ0A      NaN     C001070     1828.0      N00027503
# ..                        ...      ...         ...        ...            ...
# 459                       NaN      NaN     S001227        NaN            NaN
# 460                       NaN      NaN     V000137        NaN            NaN
# 461                       NaN      NaN     F000479        NaN            NaN
# 536                       NaN      NaN     R000618        NaN            NaN
# 538                       NaN      NaN     B001320        NaN            NaN
#
#     lis_id              fec_ids  cspan_id  govtrack_id  votesmart_id  \
# 0     S307  H2OH13033,S6OH00163    5051.0       400050       27018.0
# 1     S275  S8WA00194,H2WA01054   26137.0       300018       27122.0
# 2     S308  H6MD03177,S6MD03177    4004.0       400064       26888.0
# 3     S277            S8DE00079     663.0       300019       22421.0
# 4     S309            S6PA00217   47036.0       412246        2541.0
# ..     ...                  ...       ...          ...           ...
# 459   S420            S2MO00544       NaN       456875      104474.0
# 460   S421            S2OH00436       NaN       456876           NaN
# 461   S418            S6PA00274       NaN       456877      166286.0
# 536   S423            S6NE00129   61233.0       456952       57777.0
# 538   S424                  NaN       NaN       456954           NaN
#
#       ballotpedia_id  washington_post_id  icpsr_id     wikipedia_id
# 0      Sherrod Brown                 NaN   29389.0    Sherrod Brown
# 1     Maria Cantwell                 NaN   39310.0   Maria Cantwell
# 2         Ben Cardin                 NaN   15408.0       Ben Cardin
# 3         Tom Carper                 NaN   15015.0       Tom Carper
# 4     Bob Casey, Jr.                 NaN   40703.0    Bob Casey Jr.
# ..               ...                 ...       ...              ...
# 459     Eric Schmitt                 NaN       NaN     Eric Schmitt
# 460       J.D. Vance                 NaN       NaN      J. D. Vance
# 461   John Fetterman                 NaN       NaN   John Fetterman
# 536    Pete Ricketts                 NaN       NaN    Pete Ricketts
# 538  Laphonza Butler                 NaN       NaN  Laphonza Butler
#
# [100 rows x 36 columns]

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# Using groupby to count members in each political party.

# %%
df_house_party = df_house.groupby('party').agg('count').reset_index()
df_house_party
# Out:
#         party  last_name  first_name  middle_name  suffix  nickname  \
# 0    Democrat        215         215          109       9         9
# 1  Republican        224         224          117       8        13
#
#    full_name  birthday  gender  type  state  district  senate_class  url  \
# 0        215       215     215   215    215       215             0  213
# 1        224       224     224   224    224       224             0  221
#
#    address  phone  contact_form  rss_url  twitter  twitter_id  facebook  \
# 0      215    215             0       92      198         198       121
# 1      224    224             0       63      202         202       106
#
#    youtube  youtube_id  mastodon  bioguide_id  thomas_id  opensecrets_id  \
# 0       85         109        15          215        109             181
# 1       61          94         0          224         86             183
#
#    lis_id  fec_ids  cspan_id  govtrack_id  votesmart_id  ballotpedia_id  \
# 0       0      215       122          215           199             172
# 1       0      224       107          224           192             175
#
#    washington_post_id  icpsr_id  wikipedia_id
# 0                   0       160           215
# 1                   0       134           224

# %% [markdown]
# Number of each member in house

# %%
democrats_in_house = 215
republicans_in_house = 224

# %% [markdown]
# Finding the youngest member Democrat and Republican by using the sort_values function.

# %%
df_young_rep = df_house[df_house.party == "Republican"]
df_young_dem = df_house[df_house.party == "Democrat"]

df_young_rep_bd = df_young_rep.sort_values("birthday", ascending=False)
df_young_dem_bd = df_young_dem.sort_values("birthday", ascending=False)

# %%
df_young_rep_bd
# Out:
#         last_name first_name       middle_name suffix nickname  \
# 475  Paulina Luna       Anna         (Paulina)    NaN      NaN
# 513        Miller        Max           Leonard    NaN      NaN
# 505        Santos     George  Anthony Devolder    NaN      NaN
# 413      LaTurner      Jacob               NaN    NaN     Jake
# 398       Cammack  Katherine               NaN    NaN      Kat
# ..            ...        ...               ...    ...      ...
# 329         Baird      James                R.    NaN      NaN
# 65           Foxx   Virginia               NaN    NaN      NaN
# 68        Granger        Kay               NaN    NaN      NaN
# 41         Carter       John                R.    NaN      NaN
# 130        Rogers     Harold               NaN    NaN      Hal
#
#              full_name    birthday gender type state  district  senate_class  \
# 475  Anna Paulina Luna  1989-05-06      F  rep    FL      13.0           NaN
# 513      Max L. Miller  1988-11-13      M  rep    OH       7.0           NaN
# 505      George Santos  1988-07-22      M  rep    NY       3.0           NaN
# 413      Jake LaTurner  1988-02-17      M  rep    KS       2.0           NaN
# 398        Kat Cammack  1988-02-16      F  rep    FL       3.0           NaN
# ..                 ...         ...    ...  ...   ...       ...           ...
# 329     James R. Baird  1945-06-04      M  rep    IN       4.0           NaN
# 65       Virginia Foxx  1943-06-29      F  rep    NC       5.0           NaN
# 68         Kay Granger  1943-01-18      F  rep    TX      12.0           NaN
# 41      John R. Carter  1941-11-06      M  rep    TX      31.0           NaN
# 130      Harold Rogers  1937-12-31      M  rep    KY       5.0           NaN
#
#           party                           url  \
# 475  Republican       https://luna.house.gov/
# 513  Republican  https://maxmiller.house.gov/
# 505  Republican     https://santos.house.gov/
# 413  Republican    https://laturner.house.gov
# 398  Republican     https://cammack.house.gov
# ..          ...                           ...
# 329  Republican       https://baird.house.gov
# 65   Republican        https://foxx.house.gov
# 68   Republican  https://kaygranger.house.gov
# 41   Republican      https://carter.house.gov
# 130  Republican   https://halrogers.house.gov
#
#                                                address         phone  \
# 475  1017 Longworth House Office Building Washingto...  202-225-5961
# 513  143 Cannon House Office Building Washington DC...  202-225-3876
# 505  1117 Longworth House Office Building Washingto...  202-225-3335
# 413  2441 Rayburn House Office Building Washington ...  202-225-6601
# 398  2421 Rayburn House Office Building Washington ...  202-225-5744
# ..                                                 ...           ...
# 329  2303 Rayburn House Office Building Washington ...  202-225-5037
# 65   2462 Rayburn House Office Building Washington ...  202-225-2071
# 68   2308 Rayburn House Office Building Washington ...  202-225-5071
# 41   2208 Rayburn House Office Building Washington ...  202-225-3864
# 130  2406 Rayburn House Office Building Washington ...  202-225-4601
#
#     contact_form                                     rss_url        twitter  \
# 475          NaN                                         NaN        RepLuna
# 513          NaN                                         NaN            NaN
# 505          NaN                                         NaN            NaN
# 413          NaN                                         NaN    RepLaTurner
# 398          NaN                                         NaN  RepKatCammack
# ..           ...                                         ...            ...
# 329          NaN                                         NaN    RepJimBaird
# 65           NaN    http://foxx.house.gov/common/rss/?rss=55   VirginiaFoxx
# 68           NaN         http://kaygranger.house.gov/rss.xml  RepKayGranger
# 41           NaN  http://carter.house.gov/common/rss/?rss=40    JudgeCarter
# 130          NaN    http://halrogers.house.gov/news/rss.aspx   RepHalRogers
#
#        twitter_id              facebook          youtube  \
# 475  1.610231e+18                   NaN              NaN
# 513           NaN                   NaN              NaN
# 505           NaN                   NaN              NaN
# 413  1.345851e+18                   NaN              NaN
# 398  1.344326e+18                   NaN              NaN
# ..            ...                   ...              ...
# 329  1.086316e+18                   NaN              NaN
# 65   1.625627e+07       RepVirginiaFoxx  repvirginiafoxx
# 68   1.617437e+08         RepKayGranger    RepKayGranger
# 41   1.803043e+07           judgecarter    repjohncarter
# 130  5.504018e+08  CongressmanHalRogers     RepHalRogers
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 475                       NaN      NaN     L000596        NaN            NaN
# 513                       NaN      NaN     M001222        NaN            NaN
# 505                       NaN      NaN     S001222        NaN            NaN
# 413                       NaN      NaN     L000266        NaN      N00044232
# 398                       NaN      NaN     C001039        NaN      N00045978
# ..                        ...      ...         ...        ...            ...
# 329                       NaN      NaN     B001307        NaN      N00041954
# 65   UCggineJcxJn80TRXxdQbx6w      NaN     F000450     1791.0      N00026166
# 68   UCsRMtemAkyLh78MPES6gMVQ      NaN     G000377     1487.0      N00008799
# 41   UC9pkaOrhPfouzkJ8oAdI-1w      NaN     C001051     1752.0      N00025095
# 130  UChVFKLZkRoHQDhp4zNvEezQ      NaN     R000395      977.0      N00003473
#
#     lis_id    fec_ids   cspan_id  govtrack_id  votesmart_id  \
# 475    NaN  H0FL13158        NaN       456891      191344.0
# 513    NaN  H2OH16051        NaN       456929      206947.0
# 505    NaN  H0NY03083        NaN       456921      191234.0
# 413    NaN  H0KS02188        NaN       456824           NaN
# 398    NaN  H0FL03175        NaN       456806           NaN
# ..     ...        ...        ...          ...           ...
# 329    NaN  H8IN04199        NaN       412777       86013.0
# 65     NaN  H4NC05146  1013052.0       400643        6051.0
# 68     NaN  H6TX12060    45709.0       400157         334.0
# 41     NaN  H2TX31044  1004257.0       400068       49296.0
# 130    NaN  H0KY05015     6739.0       400340       26875.0
#
#              ballotpedia_id  washington_post_id  icpsr_id  \
# 475       Anna Paulina Luna                 NaN       NaN
# 513                     NaN                 NaN       NaN
# 505  George Devolder-Santos                 NaN       NaN
# 413                     NaN                 NaN       NaN
# 398                     NaN                 NaN       NaN
# ..                      ...                 ...       ...
# 329             James Baird                 NaN   21903.0
# 65            Virginia Foxx                 NaN   20521.0
# 68              Kay Granger                 NaN   29762.0
# 41              John Carter                 NaN   20356.0
# 130           Harold Rogers                 NaN   14854.0
#
#                        wikipedia_id
# 475               Anna Paulina Luna
# 513         Max Miller (politician)
# 505                   George Santos
# 413                   Jake LaTurner
# 398                     Kat Cammack
# ..                              ...
# 329          Jim Baird (politician)
# 65                    Virginia Foxx
# 68                      Kay Granger
# 41   John Carter (Texas politician)
# 130                      Hal Rogers
#
# [224 rows x 36 columns]

# %%
df_young_dem_bd
# Out:
#              last_name  first_name middle_name suffix nickname  \
# 474              Frost     Maxwell   Alejandro    NaN      NaN
# 349      Ocasio-Cortez  Alexandria         NaN    NaN      NaN
# 529              Casar    Gregorio     Eduardo    NaN      NaN
# 396             Jacobs        Sara         NaN    NaN      NaN
# 533  Gluesenkamp Perez       Marie         NaN    NaN      NaN
# ..                 ...         ...         ...    ...      ...
# 81               Hoyer       Steny          H.    NaN      NaN
# 162             Waters      Maxine         NaN    NaN      NaN
# 121             Norton     Eleanor      Holmes    NaN      NaN
# 123           Pascrell        Bill          J.    Jr.      NaN
# 119         Napolitano       Grace          F.    NaN      NaN
#
#                     full_name    birthday gender type state  district  \
# 474             Maxwell Frost  1997-01-17      M  rep    FL      10.0
# 349  Alexandria Ocasio-Cortez  1989-10-13      F  rep    NY      14.0
# 529                Greg Casar  1989-05-04      M  rep    TX      35.0
# 396               Sara Jacobs  1989-02-01      F  rep    CA      51.0
# 533   Marie Gluesenkamp Perez  1988-06-06      F  rep    WA       3.0
# ..                        ...         ...    ...  ...   ...       ...
# 81             Steny H. Hoyer  1939-06-14      M  rep    MD       5.0
# 162             Maxine Waters  1938-08-15      F  rep    CA      43.0
# 121     Eleanor Holmes Norton  1937-06-13      F  rep    DC       0.0
# 123        Bill Pascrell, Jr.  1937-01-25      M  rep    NJ       9.0
# 119       Grace F. Napolitano  1936-12-04      F  rep    CA      31.0
#
#      senate_class     party                                  url  \
# 474           NaN  Democrat             https://frost.house.gov/
# 349           NaN  Democrat      https://ocasio-cortez.house.gov
# 529           NaN  Democrat             https://casar.house.gov/
# 396           NaN  Democrat         https://sarajacobs.house.gov
# 533           NaN  Democrat  https://gluesenkampperez.house.gov/
# ..            ...       ...                                  ...
# 81            NaN  Democrat              https://hoyer.house.gov
# 162           NaN  Democrat             https://waters.house.gov
# 121           NaN  Democrat             https://norton.house.gov
# 123           NaN  Democrat           https://pascrell.house.gov
# 119           NaN  Democrat         https://napolitano.house.gov
#
#                                                address         phone  \
# 474  1224 Longworth House Office Building Washingto...  202-225-2176
# 349  250 Cannon House Office Building Washington DC...  202-225-3965
# 529  1339 Longworth House Office Building Washingto...  202-225-5645
# 396  1314 Longworth House Office Building Washingto...  202-225-2040
# 533  1431 Longworth House Office Building Washingto...  202-225-3536
# ..                                                 ...           ...
# 81   1705 Longworth House Office Building Washingto...  202-225-4131
# 162  2221 Rayburn House Office Building Washington ...  202-225-2201
# 121  2136 Rayburn House Office Building Washington ...  202-225-8050
# 123  2409 Rayburn House Office Building Washington ...  202-225-5751
# 119  1610 Longworth House Office Building Washingto...  202-225-5256
#
#     contact_form                                            rss_url  \
# 474          NaN                                                NaN
# 349          NaN                                                NaN
# 529          NaN                                                NaN
# 396          NaN                                                NaN
# 533          NaN                                                NaN
# ..           ...                                                ...
# 81           NaN  http://hoyer.house.gov/index.php?format=feed&a...
# 162          NaN              http://waters.house.gov/news/rss.aspx
# 121          NaN  http://norton.house.gov/index.php?format=feed&...
# 123          NaN  http://www.house.gov/apps/list/press/nj08_pasc...
# 119          NaN                http://napolitano.house.gov/rss.xml
#
#              twitter    twitter_id             facebook             youtube  \
# 474  RepMaxwellFrost  1.608494e+18                  NaN                 NaN
# 349           RepAOC  1.079105e+18                  NaN                 NaN
# 529         RepCasar  1.499512e+18                  NaN                 NaN
# 396    RepSaraJacobs  1.345104e+18                  NaN                 NaN
# 533           RepMGP  1.603128e+18                  NaN                 NaN
# ..               ...           ...                  ...                 ...
# 81     RepStenyHoyer  2.201209e+07            WhipHoyer         LeaderHoyer
# 162  RepMaxineWaters  3.668604e+07         MaxineWaters        MaxineWaters
# 121    EleanorNorton  2.360026e+07  CongresswomanNorton      EleanorHNorton
# 123     BillPascrell  7.450826e+07             pascrell         RepPascrell
# 119  GraceNapolitano  1.614111e+08   RepGraceNapolitano  RepGraceNapolitano
#
#                    youtube_id                              mastodon  \
# 474                       NaN                                   NaN
# 349                       NaN                                   NaN
# 529                       NaN                                   NaN
# 396                       NaN                                   NaN
# 533                       NaN                                   NaN
# ..                        ...                                   ...
# 81   UCvxgqX65cdhHNjJn64cgY9g                                   NaN
# 162  UCOQ2js1VYFlo74n7Ns8WsLQ                                   NaN
# 121  UChRrAXUGylfxJjbquC6aUjQ  @CongresswomanNorton@Mastodon.social
# 123  UCIy1Ru8oA14aRjpq6L3i-EQ                                   NaN
# 119  UCPWjmiAIR04oQ8QMoOWcDtA                                   NaN
#
#     bioguide_id  thomas_id opensecrets_id lis_id    fec_ids  cspan_id  \
# 474     F000476        NaN            NaN    NaN  H2FL10259       NaN
# 349     O000172        NaN      N00041162    NaN  H8NY15148       NaN
# 529     C001131        NaN            NaN    NaN  H2TX35144       NaN
# 396     J000305        NaN      N00042081    NaN  H8CA49074       NaN
# 533     G000600        NaN            NaN    NaN  H2WA03217       NaN
# ..          ...        ...            ...    ...        ...       ...
# 81      H000874      566.0      N00001821    NaN  H2MD05155    1919.0
# 162     W000187     1205.0      N00006690    NaN  H4CA23011    1953.0
# 121     N000147      868.0      N00001692    NaN  H0DC00058     882.0
# 123     P000096     1510.0      N00000751    NaN  H6NJ08118   45543.0
# 119     N000179     1602.0      N00006789    NaN  H8CA34068   57873.0
#
#      govtrack_id  votesmart_id            ballotpedia_id  washington_post_id  \
# 474       456890      209096.0                       NaN                 NaN
# 349       412804      180416.0  Alexandria Ocasio-Cortez                 NaN
# 529       456945      161953.0                       NaN                 NaN
# 396       456804           NaN                       NaN                 NaN
# 533       456949      207307.0   Marie Gluesenkamp Perez                 NaN
# ..           ...           ...                       ...                 ...
# 81        400189       26890.0               Steny Hoyer                 NaN
# 162       400422       26759.0             Maxine Waters                 NaN
# 121       400295         775.0                       NaN                 NaN
# 123       400309         478.0             Bill Pascrell                 NaN
# 119       400290        8393.0          Grace Napolitano                 NaN
#
#      icpsr_id              wikipedia_id
# 474       NaN             Maxwell Frost
# 349   21949.0  Alexandria Ocasio-Cortez
# 529       NaN                Greg Casar
# 396       NaN               Sara Jacobs
# 533       NaN   Marie Gluesenkamp Perez
# ..        ...                       ...
# 81    14873.0               Steny Hoyer
# 162   29106.0             Maxine Waters
# 121       NaN     Eleanor Holmes Norton
# 123   29741.0             Bill Pascrell
# 119   29903.0          Grace Napolitano
#
# [215 rows x 36 columns]

# %% [markdown]
# Youngest Democrat and Republican:

# %%
youngest_democrat_in_house = "Maxwell Frost"
youngest_republican_in_house = "Anna Paulina Luna"

# %% [markdown]
# <hr style="color: #DD3403;">
